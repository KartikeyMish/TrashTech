# %% [markdown]
# ### **Waste Garbage Classification Using  Pre-train VGG - 16 Using Transfer Learning and Fine Tuning**
#
# The difference between Transfer Learning and Fine-Tuning is that
#
# * In Transfer Learning, we only optimize the weights of the new classification layers we have added, while we keep the weights of the original VGG16 model.
#
# * In Fine-Tuning we optimize both the weights of the new classification layers we have added, as well as some or all of the layers from the VGG16 model.

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os
import cv2
import sklearn 
import tensorflow as tf
from tensorflow import keras
from PIL import Image as im
from glob import glob
from sklearn.model_selection import train_test_split
import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from PIL import Image as im
import cv2

# %%
# Set seeds to make the experiment more reproducible.
import random
def seed_everything(seed = 0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
seed = 0
seed_everything(seed)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
BATCH_SIZE = 64
img_height = 244
img_width = 244

# %% [markdown]
# # **Load Datasets**

# %%
import os
data_path = 'DataSets'
os.listdir(data_path)
# Out:
# ['test', 'train']

# %%
input_path = data_path
train_data_dir = input_path + '/' + 'train'
test_data_dir = input_path + '/' + 'test'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_data_dir,
    validation_split = 0.2,
    subset = 'training',
    label_mode = 'categorical',
    image_size = (img_height, img_width),
    batch_size = BATCH_SIZE,
    seed = 123)
# Out:
# Found 2048 files belonging to 6 classes.
# Using 1639 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    train_data_dir,
    validation_split = 0.2,
    subset = 'validation',
    label_mode = 'categorical',
    image_size = (img_height, img_width),
    batch_size = BATCH_SIZE,
    seed = 123)
# Out:
# Found 2048 files belonging to 6 classes.
# Using 409 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# # **DataSets Visualizations**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(len(class_names)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[i])
    plt.axis("off")

# %%
data_augmentation = keras.Sequential([
    #layers.CenterCrop(125, 125),
    layers.RandomFlip('horizontal', input_shape = (img_height, img_width, 3)),
    layers.RandomRotation(0.2, fill_mode = 'nearest'),
    layers.RandomZoom(0.1),
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(len(class_names)):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
   # plt.title(class_names[2])
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x00000296BAC47430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x00000296BAC3E670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# # **Model Architecture**
#
# *   **VGG-16 Base Model**

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = (img_height, img_width, 3)
base_model = tf.keras.applications.VGG16(input_shape = IMG_SHAPE,
                                         include_top = False,
                                         weights = 'imagenet')
#base_model.trainable = False
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 244, 244, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 244, 244, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 244, 244, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 122, 122, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 122, 122, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 122, 122, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 61, 61, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 61, 61, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 30, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 30, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def print_layer_trainable():
    for layer in base_model.layers:
        print("{0}:\t{1}".format(layer.trainable, layer.name))

# %%
print_layer_trainable()
# Out:
# True:	input_2
# True:	block1_conv1
# True:	block1_conv2
# True:	block1_pool
# True:	block2_conv1
# True:	block2_conv2
# True:	block2_pool
# True:	block3_conv1
# True:	block3_conv2
# True:	block3_conv3
# True:	block3_pool
# True:	block4_conv1
# True:	block4_conv2
# True:	block4_conv3
# True:	block4_pool
# True:	block5_conv1
# True:	block5_conv2
# True:	block5_conv3
# True:	block5_pool

# %% [markdown]
# **Fix the weights**

# %%
base_model.trainable = False

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
print_layer_trainable()
# Out:
# False:	input_2
# False:	block1_conv1
# False:	block1_conv2
# False:	block1_pool
# False:	block2_conv1
# False:	block2_conv2
# False:	block2_pool
# False:	block3_conv1
# False:	block3_conv2
# False:	block3_conv3
# False:	block3_pool
# False:	block4_conv1
# False:	block4_conv2
# False:	block4_conv3
# False:	block4_pool
# False:	block5_conv1
# False:	block5_conv2
# False:	block5_conv3
# False:	block5_pool

# %%
n_classes = len(class_names)

model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation = 'relu'),
    layers.Dropout(0.5),
    layers.Dense(n_classes, activation = 'softmax')
])

# %% [markdown]
# ### **Transfer Learning**

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 244, 244, 3)       0
#
#  rescaling_7 (Rescaling)     (None, 244, 244, 3)       0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_7   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_19 (Dense)            (None, 128)               65664
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_20 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 14,781,255
# Trainable params: 13,045,767
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
# Model Chackpoint
tl_checkpoint_1 = ModelCheckpoint(filepath = 'vgg16_best_weights.hdf5', save_best_only = True, verbose = 0)

# EarlyStopping
early_stop = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True, mode = 'min')

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor = 'val_loss', patience = 3, verbose = 1, factor = 0.5, min_lr = 0.000001)

# %%
# %%time
history = model.fit(train_ds,
                    epochs = 20,
                    validation_data = val_ds,
                    callbacks = [tl_checkpoint_1, early_stop, rop_callback])
# Out:
# Epoch 1/20
# 28/28 [==============================] - 33s 1s/step - loss: 1.5155 - accuracy: 0.4183 - val_loss: 1.1016 - val_accuracy: 0.5881 - lr: 0.0010
# Epoch 2/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.8615 - accuracy: 0.6983 - val_loss: 0.9346 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 3/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.7483 - accuracy: 0.7594 - val_loss: 0.7631 - val_accuracy: 0.7506 - lr: 0.0010
# Epoch 4/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.6204 - accuracy: 0.7926 - val_loss: 0.8212 - val_accuracy: 0.7689 - lr: 0.0010
# Epoch 5/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.6081 - accuracy: 0.7960 - val_loss: 0.9392 - val_accuracy: 0.7437 - lr: 0.0010
# Epoch 6/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.5768 - accuracy: 0.8017 - val_loss: 0.7571 - val_accuracy: 0.7506 - lr: 0.0010
# Epoch 7/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.5366 - accuracy: 0.8211 - val_loss: 0.9410 - val_accuracy: 0.7437 - lr: 0.0010
# Epoch 8/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.4873 - accuracy: 0.8303 - val_loss: 0.7218 - val_accuracy: 0.7757 - lr: 0.0010
# Epoch 9/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.5410 - accuracy: 0.8143 - val_loss: 1.0539 - val_accuracy: 0.6911 - lr: 0.0010
# Epoch 10/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.5878 - accuracy: 0.8063 - val_loss: 0.9704 - val_accuracy: 0.7506 - lr: 0.0010
# Epoch 11/20
# 28/28 [==============================] - ETA: 0s - loss: 0.5106 - accuracy: 0.8234
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 31s 1s/step - loss: 0.5106 - accuracy: 0.8234 - val_loss: 0.7682 - val_accuracy: 0.7986 - lr: 0.0010
# Epoch 12/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.3833 - accuracy: 0.8857 - val_loss: 0.7173 - val_accuracy: 0.7986 - lr: 5.0000e-04
# Epoch 13/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.4233 - accuracy: 0.8669 - val_loss: 0.7420 - val_accuracy: 0.7986 - lr: 5.0000e-04
# Epoch 14/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.3607 - accuracy: 0.8800 - val_loss: 0.7312 - val_accuracy: 0.7963 - lr: 5.0000e-04
# Epoch 15/20
# 28/28 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8806
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 31s 1s/step - loss: 0.3649 - accuracy: 0.8806 - val_loss: 0.9691 - val_accuracy: 0.7735 - lr: 5.0000e-04
# Epoch 16/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.2829 - accuracy: 0.9074 - val_loss: 0.6510 - val_accuracy: 0.7963 - lr: 2.5000e-04
# Epoch 17/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.2832 - accuracy: 0.9057 - val_loss: 0.6905 - val_accuracy: 0.7986 - lr: 2.5000e-04
# Epoch 18/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.2393 - accuracy: 0.9234 - val_loss: 0.7347 - val_accuracy: 0.8009 - lr: 2.5000e-04
# Epoch 19/20
# 28/28 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9314
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 28/28 [==============================] - 31s 1s/step - loss: 0.2258 - accuracy: 0.9314 - val_loss: 0.7120 - val_accuracy: 0.8101 - lr: 2.5000e-04
# Epoch 20/20
# 28/28 [==============================] - 31s 1s/step - loss: 0.2187 - accuracy: 0.9303 - val_loss: 0.7344 - val_accuracy: 0.8146 - lr: 1.2500e-04
# CPU times: user 3min 34s, sys: 9.33 s, total: 3min 43s
# Wall time: 12min 10s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(20)

plt.figure(figsize = (20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label = 'Training Accuracy')
plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = 'Training Loss')
plt.plot(epochs_range, val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_data_dir,
    label_mode = 'categorical',
    image_size = (img_height, img_width),
    batch_size = 1,
    seed = 123)

test_ds = test_ds.cache().prefetch(buffer_size = AUTOTUNE)
# Out:
# Found 564 files belonging to 7 classes.

# %%
# Generate predictions
model.load_weights('/content/vgg16_best_weights.hdf5') # initialize the best trained weights
preds = model.predict(test_ds)
pred_classes = np.argmax(preds, axis = 1)

# %%
model.evaluate(test_ds, verbose = 1)
# Out:
# 564/564 [==============================] - 22s 39ms/step - loss: 0.9833 - accuracy: 0.7252
# [0.9832523465156555, 0.7251772880554199]

# %% [markdown]
# # **Fine Tuning**

# %%
fine_tune  = base_model

# %%
fine_tune.trainable = True

# %%
for layer in fine_tune.layers:
    # Boolean whether this layer is trainable.
    trainable = ('block5' in layer.name or 'block4' in layer.name)
    
    # Set the layer's bool.
    layer.trainable = trainable

# %%
print_layer_trainable()
# Out:
# False:	input_2
# False:	block1_conv1
# False:	block1_conv2
# False:	block1_pool
# False:	block2_conv1
# False:	block2_conv2
# False:	block2_pool
# False:	block3_conv1
# False:	block3_conv2
# False:	block3_conv3
# False:	block3_pool
# True:	block4_conv1
# True:	block4_conv2
# True:	block4_conv3
# True:	block4_pool
# True:	block5_conv1
# True:	block5_conv2
# True:	block5_conv3
# True:	block5_pool

# %%
fine_tune.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 244, 244, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 244, 244, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 244, 244, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 122, 122, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 122, 122, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 122, 122, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 61, 61, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 61, 61, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 30, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 30, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 12,979,200
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
n_classes = len(class_names)

model2 = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    fine_tune,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation = 'relu'),
    layers.Dropout(0.5),
    layers.Dense(n_classes, activation = 'softmax')
])

# %%
model2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 244, 244, 3)       0
#
#  rescaling_9 (Rescaling)     (None, 244, 244, 3)       0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_9   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_24 (Dense)            (None, 128)               65664
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_25 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 14,781,255
# Trainable params: 13,045,767
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
model2.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
# Model Chackpoint
tl_checkpoint_1 = ModelCheckpoint(filepath = 'vgg16_best_weights_fine_tuning.hdf5', save_best_only = True, verbose = 0)

# EarlyStopping
early_stop = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True, mode = 'min')

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor = 'val_loss', patience = 3, verbose = 1, factor = 0.5, min_lr = 0.000001)

# %%
# %%time
history = model2.fit(train_ds,
                    epochs = 25,
                    validation_data = val_ds,
                    callbacks = [tl_checkpoint_1, early_stop, rop_callback])
# Out:
# Epoch 1/25
# 28/28 [==============================] - 39s 1s/step - loss: 1.3681 - accuracy: 0.5429 - val_loss: 0.9493 - val_accuracy: 0.7414 - lr: 0.0010
# Epoch 2/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.8220 - accuracy: 0.7251 - val_loss: 0.8848 - val_accuracy: 0.7162 - lr: 0.0010
# Epoch 3/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.5727 - accuracy: 0.8074 - val_loss: 0.6555 - val_accuracy: 0.7712 - lr: 0.0010
# Epoch 4/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.5256 - accuracy: 0.8411 - val_loss: 0.7150 - val_accuracy: 0.7620 - lr: 0.0010
# Epoch 5/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.5033 - accuracy: 0.8371 - val_loss: 0.8382 - val_accuracy: 0.7735 - lr: 0.0010
# Epoch 6/25
# 28/28 [==============================] - ETA: 0s - loss: 0.4742 - accuracy: 0.8406
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 31s 1s/step - loss: 0.4742 - accuracy: 0.8406 - val_loss: 0.7400 - val_accuracy: 0.7780 - lr: 0.0010
# Epoch 7/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.3632 - accuracy: 0.8777 - val_loss: 0.7714 - val_accuracy: 0.7872 - lr: 5.0000e-04
# Epoch 8/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.3239 - accuracy: 0.8949 - val_loss: 0.8985 - val_accuracy: 0.7803 - lr: 5.0000e-04
# Epoch 9/25
# 28/28 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.9011
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 31s 1s/step - loss: 0.3057 - accuracy: 0.9011 - val_loss: 0.7053 - val_accuracy: 0.7941 - lr: 5.0000e-04
# Epoch 10/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.2533 - accuracy: 0.9137 - val_loss: 0.7824 - val_accuracy: 0.7986 - lr: 2.5000e-04
# Epoch 11/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.2412 - accuracy: 0.9177 - val_loss: 0.6357 - val_accuracy: 0.8215 - lr: 2.5000e-04
# Epoch 12/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.2255 - accuracy: 0.9234 - val_loss: 0.6071 - val_accuracy: 0.8215 - lr: 2.5000e-04
# Epoch 13/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1986 - accuracy: 0.9331 - val_loss: 0.8005 - val_accuracy: 0.7963 - lr: 2.5000e-04
# Epoch 14/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1795 - accuracy: 0.9366 - val_loss: 0.7866 - val_accuracy: 0.7872 - lr: 2.5000e-04
# Epoch 15/25
# 28/28 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.9320
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 28/28 [==============================] - 31s 1s/step - loss: 0.2003 - accuracy: 0.9320 - val_loss: 0.7853 - val_accuracy: 0.8009 - lr: 2.5000e-04
# Epoch 16/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1773 - accuracy: 0.9417 - val_loss: 0.7061 - val_accuracy: 0.8192 - lr: 1.2500e-04
# Epoch 17/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1588 - accuracy: 0.9480 - val_loss: 0.7783 - val_accuracy: 0.8032 - lr: 1.2500e-04
# Epoch 18/25
# 28/28 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9474
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 28/28 [==============================] - 31s 1s/step - loss: 0.1629 - accuracy: 0.9474 - val_loss: 0.6677 - val_accuracy: 0.8261 - lr: 1.2500e-04
# Epoch 19/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1490 - accuracy: 0.9480 - val_loss: 0.6605 - val_accuracy: 0.8124 - lr: 6.2500e-05
# Epoch 20/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1343 - accuracy: 0.9566 - val_loss: 0.6672 - val_accuracy: 0.8261 - lr: 6.2500e-05
# Epoch 21/25
# 28/28 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9457
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 28/28 [==============================] - 31s 1s/step - loss: 0.1470 - accuracy: 0.9457 - val_loss: 0.7202 - val_accuracy: 0.8261 - lr: 6.2500e-05
# Epoch 22/25
# 28/28 [==============================] - 31s 1s/step - loss: 0.1356 - accuracy: 0.9514 - val_loss: 0.7122 - val_accuracy: 0.8169 - lr: 3.1250e-05
# CPU times: user 3min 55s, sys: 9.03 s, total: 4min 4s
# Wall time: 12min 55s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(22)

plt.figure(figsize = (20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label = 'Training Accuracy')
plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = 'Training Loss')
plt.plot(epochs_range, val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_data_dir,
    label_mode = 'categorical',
    image_size = (img_height, img_width),
    batch_size = 1,
    seed = 123)

test_ds = test_ds.cache().prefetch(buffer_size = AUTOTUNE)
# Out:
# Found 564 files belonging to 7 classes.

# %%
# Generate predictions
model2.load_weights('/content/vgg16_best_weights_fine_tuning.hdf5') # initialize the best trained weights
preds = model2.predict(test_ds)
pred_classes = np.argmax(preds, axis = 1)

# %%
model2.evaluate(test_ds, verbose = 1)
# Out:
# 564/564 [==============================] - 22s 40ms/step - loss: 0.7993 - accuracy: 0.8085
# [0.7993292808532715, 0.8085106611251831]

# %% [markdown]
# # **Concludes**
#
# **Accuracy On Transfer Learning : 72.5%** </br>
# **Accuracy On Fine Tuning : 80.8%**</br>
